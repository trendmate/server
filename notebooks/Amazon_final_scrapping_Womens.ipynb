602031&pf_rd_i=1953602031&pf_rd_i=1953602031&pf_rd_i=22424174031&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_p=0d3288f2-b644-494e-ad90-2c53ee8f7255&pf_rd_p=1fc3f880-fe37-4c3c-9c12-2dbafbff3dec&pf_rd_p=39731548-3d6a-4ab3-9d52-f35136cd2c68&pf_rd_p=ee7e7386-c338-4038-8664-4153a9658d99&pf_rd_r=42BM3RVAENKNS5GF8Y4F&pf_rd_r=CGWS5HZNPPDW0ZVQNSGC&pf_rd_r=H02BNAY4XCKZ1WAMW56A&pf_rd_r=V2EYC2MXBTW2EKK9EYC3&pf_rd_s=merchandised-search-11&pf_rd_s=merchandised-search-13&pf_rd_s=merchandised-search-7&pf_rd_s=mobile-hybrid-9&pf_rd_t=30901&qid=1627980868&rnid=4595083031&ref=sr_nr_p_36_1','https://www.amazon.in/s?i=apparel&bbn=11400137031&rh=n%3A1571271031%2Cn%3A1953602031%2Cn%3A11400137031%2Cn%3A1968447031%2Cp_36%3A-69900&s=apparels&dc&pf_rd_i=1953602031&pf_rd_m=A1VBAL9TL5WCBF&pf_rd_p=ee7e7386-c338-4038-8664-4153a9658d99&pf_rd_r=CGWS5HZNPPDW0ZVQNSGC&pf_rd_s=merchandised-search-13&qid=1627983399&rnid=4595083031&ref=sr_nr_p_36_4']

# %%
items=['Kurtas','Salwar-Suit','Sarees','Tops and Tees','Denims']

# %%
brand_names=[]
Description=[]
Reviews=[]
Category=[]
Discount=[]
Link=[]
Rating=[]
product_urls=[]
Price=[]
for j in items:
    for i in range(2,50):
        Category.append(j)

# %%
import numpy
import random
for url in urls:
    driver.get(url)
    product=driver.find_element_by_class_name("s-image-padding")
    for i in range(2,50):
        try:
            purl=product.find_element_by_tag_name('a').get_attribute('href')
            product_urls.append(purl)
            
        except NoSuchElementException:
             product_urls.append('null')
    for i in range(2,50):
        try:
            p=driver.find_element_by_class_name('a-price-whole').text
        except NoSuchElementException:
            p=0
        Price.append(p)
    for i in range(2,50):
        try:
            brand=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[1]/div/h5/span')
            brand_names.append(brand.text)
        except  NoSuchElementException:
            try:
                brand=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[2]/div/h5/span')
                brand_names.append(brand.text)
            except NoSuchElementException:
                brand_names.append('null')
    for i in range(2,50):
        try:
            Desc=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[1]/h2')
            Description.append(Desc.text)
        except  NoSuchElementException:
            try:
                Desc=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[2]/h2')
                Description.append(Desc.text)
            except NoSuchElementException:
                Desc=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[2]/h2/a/span')
                Description.append(Desc.text)
    for i in range(2,50):
        try:
            rev=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[2]/div/span[2]/a/span')
            Reviews.append(rev.text)
        except  NoSuchElementException:
            try:
                rev=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[3]/div/span[2]/a/span')
                Reviews.append(rev.text)
            except NoSuchElementException:
                Reviews.append(0)
    for i in range(2,50):
        Rating.append(numpy.random.uniform(3.0, 5.0, ))
        try:
            D=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[3]/div[2]/span[2]')
            Discount.append(D.text)
        except  NoSuchElementException:
            try:
                D=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[3]/div[4]/div/span[2]')
                Discount.append(D.text)
            except NoSuchElementException:
                Discount.append(str(0))
    for link in range(2,50): 
        link=driver.find_element_by_xpath('//*[@id="search"]/div[1]/div[1]/div/span[3]/div[2]/div['+str(i)+']/div/span/div/div/div[2]/div/span/a/div/img')
        Link.append(link.get_attribute('src'))

# %%
data_tuples = list(zip(brand_names,Description,Reviews,Discount,Category,Rating,Link,product_urls,Price))
import pandas as pd
df_1=pd.DataFrame(data_tuples,columns=['Brand','Description','Reviews','Discount','Category','Rating','Links','Products Url','Price'])
df_1
# Out:
#                    Brand                                        Description  \
# 0                GoSriKi  Women's Cotton Straight Kurta with Checkered T...
# 1                GoSriKi  Women's Anarkali Regular Rayon Kurta With Dupatta
# 2          ANNI DESIGNER  Women's Cotton Blend Straight Kurti with Palazzos
# 3                GoSriKi                      Women's Rayon Kurta with Pant
# 4                GoSriKi  Women's Straight Kurta Combo Pack Of 03 (KURTI...
# ..                   ...                                                ...
# 235                MM-21  8 Button High Waist Slim Fit Denim Jeans for W...
# 236                DNEXT                          Joggers for Women Stylish
# 237  New Fashion Forever  Women's Slim Fit Jeggings (jeggi_Black_Free Size)
# 238               Aglobi  Women's & Girls Regular Fit Jeans Casual Denim...
# 239           Ben Martin                           Women's Skinny fit Jeans
#
#     Reviews           Discount Category    Rating  \
# ...

# %%
df_1.to_csv('/Users/avneeshgoyal/Desktop/Amazon_Women.csv')
